# %%
import pandas as pd

# %% [markdown]
# ## task

# %% [markdown]
# 参赛方需依据厦门市大交通信息共享服务平台提供的出租车（包括巡游车和网约车）订单数据，综合应用统计分析方法对出租车载客点的空间分布特征进行量化计算，给出载客点的空间分布特征分析，并对比分析工作日和非工作日、节假日和非节假日异同；需根据景区周边出租车载客点的密度分布确定其周边载客点聚集分布的范围和强度，分析其时变特性；并结合整体分布特性给出出租车候车泊位设置建议。

# %% [markdown]
# ## GPS Data

# %%
tour = pd.read_csv('GPS_Touring.csv')
taxi = pr.read_csv('GPS_Taxi.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-bbae2f6f7aef> in <module>
# ----> 1 tour = pd.read_csv('GPS_Touring.csv')
#       2 taxi = pr.read_csv('GPS_Taxi.csv')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %% [markdown]
# ## Order Data

# %% [markdown]
# ## 五一假期厦门网约车订单数据.xlsx

# %%
xlsx_gps = pd.read_excel(data_path_org+'五一假期厦门网约车订单数据.xlsx')
xlsx_gps
# Out:
#                      订单编号 上车位置行政区划编号        车辆号牌          预计上车时间       等待时间  \
# 0                ORDER_ID    ON_AREA  VEHICLE_NO   BOOK_DEP_TIME  WAIT_TIME
# 1     6511269774274250000     350200        25A2  20180115213211          0
# 2          35197522115351     350211        6632  20190704224545        NaN
# 3          35197574629706     350203        5856  20190706234640        NaN
# 4          35197573821494     350212        3533  20190706224956        NaN
# ...                   ...        ...         ...             ...        ...
# 1088       35197571914336     350211        9W37  20190706211858        NaN
# 1089       35197561522564     350206        FC38  20190706142314        NaN
# 1090       35197574589771     350203         982  20190706234118        NaN
# 1091       35197574635557     350203        8291  20190706234525        NaN
# 1092       35197574153158     350203       20773  20190706230905        NaN
#
# ...

# %%
for n in xlsx_gps.columns:
    print(n,'/',xlsx_gps.loc[0][n])
# Out:
# 订单编号 / ORDER_ID
# 上车位置行政区划编号 / ON_AREA
# 车辆号牌 / VEHICLE_NO
# 预计上车时间 / BOOK_DEP_TIME
# 等待时间 / WAIT_TIME
# 车辆出发经度 / DEP_LONGITUDE
# 车辆出发纬度 / DEP_LATITUDE
# 上车地点 / DEP_AREA
# 上车时间 / DEP_TIME
# 车辆到达经度 / DEST_LONGITUDE
# 车辆到达纬度 / DEST_LATITUDE
# 下车地点 / DEST_AREA
# 下车时间 / DEST_TIME
# 载客里程 / DRIVE_MILE
# 载客时间 / DRIVE_TIME
# 空驶里程 / WAIT_MILE
# 订单完成时间 / ORDER_MATCH_TIME

# %%
xlsx_gps.to_csv(data_path+'Order_Taxi_51.csv')

# %% [markdown]
# ### 普通工作日及双休日厦门网约车订单数据.xlsx

# %%
xlsx_gps = pd.read_excel(data_path_org+'普通工作日及双休日厦门网约车订单数据.xlsx')
xlsx_gps
# Out:
#                      订单编号 上车位置行政区划编号        车辆号牌          预计上车时间       等待时间  \
# 0                ORDER_ID    ON_AREA  VEHICLE_NO   BOOK_DEP_TIME  WAIT_TIME
# 1     6511269774274249728     350200        25A2  20180115213211          0
# 2          35197522115351     350211        6632  20190704224545        NaN
# 3          35197574629706     350203        5856  20190706234640        NaN
# 4          35197573821494     350212        3533  20190706224956        NaN
# ...                   ...        ...         ...             ...        ...
# 1088       35197571914336     350211        9W37  20190706211858        NaN
# 1089       35197561522564     350206        FC38  20190706142314        NaN
# 1090       35197574589771     350203         982  20190706234118        NaN
# 1091       35197574635557     350203        8291  20190706234525        NaN
# 1092       35197574153158     350203       20773  20190706230905        NaN
#
# ...

# %%
for n in xlsx_gps.columns:
    print(n,'/',xlsx_gps.loc[0][n])
# Out:
# 订单编号 / ORDER_ID
# 上车位置行政区划编号 / ON_AREA
# 车辆号牌 / VEHICLE_NO
# 预计上车时间 / BOOK_DEP_TIME
# 等待时间 / WAIT_TIME
# 车辆出发经度 / DEP_LONGITUDE
# 车辆出发纬度 / DEP_LATITUDE
# 上车地点 / DEP_AREA
# 上车时间 / DEP_TIME
# 车辆到达经度 / DEST_LONGITUDE
# 车辆到达纬度 / DEST_LATITUDE
# 下车地点 / DEST_AREA
# 下车时间 / DEST_TIME
# 载客里程 / DRIVE_MILE
# 载客时间 / DRIVE_TIME
# 空驶里程 / WAIT_MILE
# 订单完成时间 / ORDER_MATCH_TIME

# %%
xlsx_gps.to_csv(data_path+'Order_Taxi.csv')
